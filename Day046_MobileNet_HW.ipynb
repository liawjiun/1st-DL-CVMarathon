# %% [markdown]
# # 作業

# %% [markdown]
# ### 嘗試用 keras 的 DepthwiseConv2D 等 layers 實做 Separable Convolution.
#    - depthwise's filter shape 爲 (3,3), padding = same
#    - pointwise's filters size 爲 128
#    - 不需要給 alpha, depth multiplier 參數

# %% [markdown]
# ##### 載入套件

# %%
from keras.models import Input, Model
from keras.layers import DepthwiseConv2D, Conv2D, BatchNormalization, ReLU
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# ##### 定義 Separable Convolution 函數 (請在此實做)

# %%
def SeparableConv(input):
  x = DepthwiseConv2D(kernel_size=3, padding = 'same', activation=None)(input)
  x = BatchNormalization() (x) 
  x = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(x)
  x = Conv2D(filters=128,kernel_size=1, padding = 'same', activation=None)(x)
  x = BatchNormalization() (x) 
  x = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(x)

  return x

# %% [markdown]
# ##### 建構模型

# %%
input = Input((64, 64, 3))
output = SeparableConv(input)
model = Model(inputs=input, outputs=output)
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_13 (InputLayer)        (None, 64, 64, 3)         0
# _________________________________________________________________
# depthwise_conv2d_9 (Depthwis (None, 64, 64, 3)         30
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64, 64, 3)         12
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 128)       512
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 64, 64, 128)       512
# _________________________________________________________________
# re_lu_6 (ReLU)               (None, 64, 64, 128)       0
# ...
