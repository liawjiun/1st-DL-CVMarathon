# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)

import os
from google.colab import drive 
drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# Out:
# `%tensorflow_version` only switches the major version: `1.x` or `2.x`.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.0
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
path = "/content/gdrive/My Drive/Colab Notebooks/Top4_CNN"
import os
os.chdir(path)
os.chdir("cupoy_cv_part4")
# !ls   #確認path已經到local目錄
# Out:
# best_weights.h5  model.h5  test.csv  training.csv  weights.h5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code

# %%
model_with_augment.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
nubr = imgs_train.shape[0]
nubr = int(nubr)
imgs_train_mirror = np.fliplr(imgs_train[0])
imgs_train_mirror = imgs_train_mirror[np.newaxis,:]
for i in range(1,nubr): #skip index 0
  img_tmp = np.fliplr(imgs_train[i])
  img_tmp = img_tmp[np.newaxis,:]
  imgs_train_mirror = np.concatenate((imgs_train_mirror,img_tmp),axis=0)

# %%
nubr_img = imgs_train.shape[0]
nubr_img = int(nubr_img)
nubr_pt = points_train[0].shape[0]
nubr_pt2 = nubr_pt/2
nubr_pt = int(nubr_pt)
nubr_pt2 = int(nubr_pt2)

points_train_mirror = points_train
for i in range(nubr_img):
  for j in range(0,nubr_pt2):
    points_train_mirror[i][2*j] = -points_train_mirror[i][2*j]

# %%
imgs_train = np.concatenate((imgs_train, imgs_train_mirror),axis=0)
points_train = np.concatenate((points_train, points_train_mirror),axis=0)

# %%
imgs_train.shape
# Out:
# (4280, 96, 96)

# %%
# training the model
hist_model_with_augment = model_with_augment.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights_with_augment.h5')
# save the model
model.save('model_with_augment.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.0050 - val_loss: 0.0016
#
# Epoch 00001: val_loss improved from inf to 0.00165, saving model to best_weights.h5
# Epoch 2/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.0014 - val_loss: 0.0016
#
# Epoch 00002: val_loss improved from 0.00165 to 0.00162, saving model to best_weights.h5
# Epoch 3/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.0012 - val_loss: 0.0015
#
# Epoch 00003: val_loss improved from 0.00162 to 0.00152, saving model to best_weights.h5
# Epoch 4/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.0010 - val_loss: 0.0014
#
# Epoch 00004: val_loss improved from 0.00152 to 0.00143, saving model to best_weights.h5
# Epoch 5/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.6901e-04 - val_loss: 0.0015
#
# Epoch 00005: val_loss did not improve from 0.00143
# Epoch 6/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 7.1898e-04 - val_loss: 0.0015
#
# Epoch 00006: val_loss did not improve from 0.00143
# Epoch 7/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 6.2981e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss did not improve from 0.00143
# Epoch 8/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 5.5778e-04 - val_loss: 0.0017
#
# Epoch 00008: val_loss did not improve from 0.00143
# Epoch 9/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 5.2483e-04 - val_loss: 0.0017
#
# Epoch 00009: val_loss did not improve from 0.00143
# Epoch 10/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 4.8724e-04 - val_loss: 0.0017
#
# Epoch 00010: val_loss did not improve from 0.00143
# Epoch 11/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 4.5693e-04 - val_loss: 0.0018
#
# Epoch 00011: val_loss did not improve from 0.00143
# Epoch 12/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 4.3378e-04 - val_loss: 0.0019
#
# Epoch 00012: val_loss did not improve from 0.00143
# Epoch 13/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 4.0935e-04 - val_loss: 0.0019
#
# Epoch 00013: val_loss did not improve from 0.00143
# Epoch 14/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.9555e-04 - val_loss: 0.0019
#
# Epoch 00014: val_loss did not improve from 0.00143
# Epoch 15/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.7665e-04 - val_loss: 0.0019
#
# Epoch 00015: val_loss did not improve from 0.00143
# Epoch 16/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.5852e-04 - val_loss: 0.0019
#
# Epoch 00016: val_loss did not improve from 0.00143
# Epoch 17/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.4500e-04 - val_loss: 0.0019
#
# Epoch 00017: val_loss did not improve from 0.00143
# Epoch 18/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.4060e-04 - val_loss: 0.0019
#
# Epoch 00018: val_loss did not improve from 0.00143
# Epoch 19/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.1821e-04 - val_loss: 0.0019
#
# Epoch 00019: val_loss did not improve from 0.00143
# Epoch 20/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.1233e-04 - val_loss: 0.0019
#
# Epoch 00020: val_loss did not improve from 0.00143
# Epoch 21/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.0638e-04 - val_loss: 0.0020
#
# Epoch 00021: val_loss did not improve from 0.00143
# Epoch 22/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.9337e-04 - val_loss: 0.0020
#
# Epoch 00022: val_loss did not improve from 0.00143
# Epoch 23/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.8829e-04 - val_loss: 0.0019
#
# Epoch 00023: val_loss did not improve from 0.00143
# Epoch 24/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.8127e-04 - val_loss: 0.0019
#
# Epoch 00024: val_loss did not improve from 0.00143
# Epoch 25/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.6994e-04 - val_loss: 0.0020
#
# Epoch 00025: val_loss did not improve from 0.00143
# Epoch 26/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.6877e-04 - val_loss: 0.0020
#
# Epoch 00026: val_loss did not improve from 0.00143
# Epoch 27/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.5983e-04 - val_loss: 0.0020
#
# Epoch 00027: val_loss did not improve from 0.00143
# Epoch 28/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.5219e-04 - val_loss: 0.0019
#
# Epoch 00028: val_loss did not improve from 0.00143
# Epoch 29/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.5446e-04 - val_loss: 0.0020
#
# Epoch 00029: val_loss did not improve from 0.00143
# Epoch 30/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.4021e-04 - val_loss: 0.0019
#
# Epoch 00030: val_loss did not improve from 0.00143
# Epoch 31/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.4332e-04 - val_loss: 0.0020
#
# Epoch 00031: val_loss did not improve from 0.00143
# Epoch 32/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.3256e-04 - val_loss: 0.0020
#
# Epoch 00032: val_loss did not improve from 0.00143
# Epoch 33/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.2324e-04 - val_loss: 0.0019
#
# Epoch 00033: val_loss did not improve from 0.00143
# Epoch 34/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.2187e-04 - val_loss: 0.0019
#
# Epoch 00034: val_loss did not improve from 0.00143
# Epoch 35/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.1460e-04 - val_loss: 0.0020
#
# Epoch 00035: val_loss did not improve from 0.00143
# Epoch 36/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.1510e-04 - val_loss: 0.0019
#
# Epoch 00036: val_loss did not improve from 0.00143
# Epoch 37/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.1273e-04 - val_loss: 0.0022
#
# Epoch 00037: val_loss did not improve from 0.00143
# Epoch 38/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.0379e-04 - val_loss: 0.0019
#
# Epoch 00038: val_loss did not improve from 0.00143
# Epoch 39/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.0713e-04 - val_loss: 0.0020
#
# Epoch 00039: val_loss did not improve from 0.00143
# Epoch 40/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.9958e-04 - val_loss: 0.0019
#
# Epoch 00040: val_loss did not improve from 0.00143
# Epoch 41/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.9335e-04 - val_loss: 0.0020
#
# Epoch 00041: val_loss did not improve from 0.00143
# Epoch 42/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.9040e-04 - val_loss: 0.0020
#
# Epoch 00042: val_loss did not improve from 0.00143
# Epoch 43/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.8772e-04 - val_loss: 0.0019
#
# Epoch 00043: val_loss did not improve from 0.00143
# Epoch 44/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.8646e-04 - val_loss: 0.0020
#
# Epoch 00044: val_loss did not improve from 0.00143
# Epoch 45/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.8535e-04 - val_loss: 0.0020
#
# Epoch 00045: val_loss did not improve from 0.00143
# Epoch 46/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.8138e-04 - val_loss: 0.0020
#
# Epoch 00046: val_loss did not improve from 0.00143
# Epoch 47/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.7738e-04 - val_loss: 0.0019
#
# Epoch 00047: val_loss did not improve from 0.00143
# Epoch 48/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.7765e-04 - val_loss: 0.0019
#
# Epoch 00048: val_loss did not improve from 0.00143
# Epoch 49/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.7329e-04 - val_loss: 0.0019
#
# Epoch 00049: val_loss did not improve from 0.00143
# Epoch 50/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.6681e-04 - val_loss: 0.0020
#
# Epoch 00050: val_loss did not improve from 0.00143
# Epoch 51/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.6571e-04 - val_loss: 0.0020
#
# Epoch 00051: val_loss did not improve from 0.00143
# Epoch 52/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.6368e-04 - val_loss: 0.0019
#
# Epoch 00052: val_loss did not improve from 0.00143
# Epoch 53/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.6506e-04 - val_loss: 0.0019
#
# Epoch 00053: val_loss did not improve from 0.00143
# Epoch 54/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5771e-04 - val_loss: 0.0019
#
# Epoch 00054: val_loss did not improve from 0.00143
# Epoch 55/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5661e-04 - val_loss: 0.0019
#
# Epoch 00055: val_loss did not improve from 0.00143
# Epoch 56/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5276e-04 - val_loss: 0.0019
#
# Epoch 00056: val_loss did not improve from 0.00143
# Epoch 57/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5085e-04 - val_loss: 0.0019
#
# Epoch 00057: val_loss did not improve from 0.00143
# Epoch 58/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5440e-04 - val_loss: 0.0019
#
# Epoch 00058: val_loss did not improve from 0.00143
# Epoch 59/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4943e-04 - val_loss: 0.0018
#
# Epoch 00059: val_loss did not improve from 0.00143
# Epoch 60/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4563e-04 - val_loss: 0.0019
#
# Epoch 00060: val_loss did not improve from 0.00143
# Epoch 61/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4369e-04 - val_loss: 0.0020
#
# Epoch 00061: val_loss did not improve from 0.00143
# Epoch 62/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4327e-04 - val_loss: 0.0019
#
# Epoch 00062: val_loss did not improve from 0.00143
# Epoch 63/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4004e-04 - val_loss: 0.0020
#
# Epoch 00063: val_loss did not improve from 0.00143
# Epoch 64/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4468e-04 - val_loss: 0.0019
#
# Epoch 00064: val_loss did not improve from 0.00143
# Epoch 65/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4066e-04 - val_loss: 0.0019
#
# Epoch 00065: val_loss did not improve from 0.00143
# Epoch 66/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3629e-04 - val_loss: 0.0019
#
# Epoch 00066: val_loss did not improve from 0.00143
# Epoch 67/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3707e-04 - val_loss: 0.0019
#
# Epoch 00067: val_loss did not improve from 0.00143
# Epoch 68/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3256e-04 - val_loss: 0.0019
#
# Epoch 00068: val_loss did not improve from 0.00143
# Epoch 69/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3056e-04 - val_loss: 0.0019
#
# Epoch 00069: val_loss did not improve from 0.00143
# Epoch 70/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.2896e-04 - val_loss: 0.0019
#
# Epoch 00070: val_loss did not improve from 0.00143
# Epoch 71/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.2984e-04 - val_loss: 0.0019
#
# Epoch 00071: val_loss did not improve from 0.00143
# Epoch 72/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3001e-04 - val_loss: 0.0019
#
# Epoch 00072: val_loss did not improve from 0.00143
# Epoch 73/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3041e-04 - val_loss: 0.0019
#
# Epoch 00073: val_loss did not improve from 0.00143
# Epoch 74/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.2823e-04 - val_loss: 0.0019
#
# Epoch 00074: val_loss did not improve from 0.00143
# Epoch 75/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.2657e-04 - val_loss: 0.0020
#
# Epoch 00075: val_loss did not improve from 0.00143
# Epoch 76/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.2716e-04 - val_loss: 0.0019
#
# Epoch 00076: val_loss did not improve from 0.00143
# Epoch 77/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.2229e-04 - val_loss: 0.0018
#
# Epoch 00077: val_loss did not improve from 0.00143
# Epoch 78/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.2308e-04 - val_loss: 0.0019
#
# Epoch 00078: val_loss did not improve from 0.00143
# Epoch 79/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.2228e-04 - val_loss: 0.0019
#
# Epoch 00079: val_loss did not improve from 0.00143
# Epoch 80/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1997e-04 - val_loss: 0.0019
#
# Epoch 00080: val_loss did not improve from 0.00143
# Epoch 81/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1884e-04 - val_loss: 0.0019
#
# Epoch 00081: val_loss did not improve from 0.00143
# Epoch 82/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1436e-04 - val_loss: 0.0019
#
# Epoch 00082: val_loss did not improve from 0.00143
# Epoch 83/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1424e-04 - val_loss: 0.0018
#
# Epoch 00083: val_loss did not improve from 0.00143
# Epoch 84/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1422e-04 - val_loss: 0.0020
#
# Epoch 00084: val_loss did not improve from 0.00143
# Epoch 85/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1569e-04 - val_loss: 0.0019
#
# Epoch 00085: val_loss did not improve from 0.00143
# Epoch 86/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1508e-04 - val_loss: 0.0019
#
# Epoch 00086: val_loss did not improve from 0.00143
# Epoch 87/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1097e-04 - val_loss: 0.0019
#
# Epoch 00087: val_loss did not improve from 0.00143
# Epoch 88/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1112e-04 - val_loss: 0.0019
#
# Epoch 00088: val_loss did not improve from 0.00143
# Epoch 89/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1413e-04 - val_loss: 0.0019
#
# Epoch 00089: val_loss did not improve from 0.00143
# Epoch 90/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1006e-04 - val_loss: 0.0019
#
# Epoch 00090: val_loss did not improve from 0.00143
# Epoch 91/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0793e-04 - val_loss: 0.0018
#
# Epoch 00091: val_loss did not improve from 0.00143
# Epoch 92/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0844e-04 - val_loss: 0.0019
#
# Epoch 00092: val_loss did not improve from 0.00143
# Epoch 93/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0639e-04 - val_loss: 0.0019
#
# Epoch 00093: val_loss did not improve from 0.00143
# Epoch 94/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0925e-04 - val_loss: 0.0019
#
# Epoch 00094: val_loss did not improve from 0.00143
# Epoch 95/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0790e-04 - val_loss: 0.0019
#
# Epoch 00095: val_loss did not improve from 0.00143
# Epoch 96/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0900e-04 - val_loss: 0.0019
#
# Epoch 00096: val_loss did not improve from 0.00143
# Epoch 97/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0651e-04 - val_loss: 0.0018
#
# Epoch 00097: val_loss did not improve from 0.00143
# Epoch 98/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0668e-04 - val_loss: 0.0018
#
# Epoch 00098: val_loss did not improve from 0.00143
# Epoch 99/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0714e-04 - val_loss: 0.0018
#
# Epoch 00099: val_loss did not improve from 0.00143
# Epoch 100/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0354e-04 - val_loss: 0.0018
#
# Epoch 00100: val_loss did not improve from 0.00143
# Epoch 101/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0648e-04 - val_loss: 0.0019
#
# Epoch 00101: val_loss did not improve from 0.00143
# Epoch 102/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0253e-04 - val_loss: 0.0019
#
# Epoch 00102: val_loss did not improve from 0.00143
# Epoch 103/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0318e-04 - val_loss: 0.0018
#
# Epoch 00103: val_loss did not improve from 0.00143
# Epoch 104/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0066e-04 - val_loss: 0.0018
#
# Epoch 00104: val_loss did not improve from 0.00143
# Epoch 105/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0259e-04 - val_loss: 0.0019
#
# Epoch 00105: val_loss did not improve from 0.00143
# Epoch 106/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0428e-04 - val_loss: 0.0018
#
# Epoch 00106: val_loss did not improve from 0.00143
# Epoch 107/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0136e-04 - val_loss: 0.0019
#
# Epoch 00107: val_loss did not improve from 0.00143
# Epoch 108/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0276e-04 - val_loss: 0.0018
#
# Epoch 00108: val_loss did not improve from 0.00143
# Epoch 109/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.9373e-05 - val_loss: 0.0019
#
# Epoch 00109: val_loss did not improve from 0.00143
# Epoch 110/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.8499e-05 - val_loss: 0.0019
#
# Epoch 00110: val_loss did not improve from 0.00143
# Epoch 111/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.9732e-05 - val_loss: 0.0019
#
# Epoch 00111: val_loss did not improve from 0.00143
# Epoch 112/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0107e-04 - val_loss: 0.0019
#
# Epoch 00112: val_loss did not improve from 0.00143
# Epoch 113/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.8568e-05 - val_loss: 0.0018
#
# Epoch 00113: val_loss did not improve from 0.00143
# Epoch 114/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0027e-04 - val_loss: 0.0019
#
# Epoch 00114: val_loss did not improve from 0.00143
# Epoch 115/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.7792e-05 - val_loss: 0.0018
#
# Epoch 00115: val_loss did not improve from 0.00143
# Epoch 116/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.9254e-05 - val_loss: 0.0019
#
# Epoch 00116: val_loss did not improve from 0.00143
# Epoch 117/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.8777e-05 - val_loss: 0.0018
#
# Epoch 00117: val_loss did not improve from 0.00143
# Epoch 118/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0046e-04 - val_loss: 0.0018
#
# Epoch 00118: val_loss did not improve from 0.00143
# Epoch 119/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.7264e-05 - val_loss: 0.0018
#
# Epoch 00119: val_loss did not improve from 0.00143
# Epoch 120/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.3270e-05 - val_loss: 0.0019
#
# Epoch 00120: val_loss did not improve from 0.00143
# Epoch 121/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.3866e-05 - val_loss: 0.0019
#
# Epoch 00121: val_loss did not improve from 0.00143
# Epoch 122/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.2700e-05 - val_loss: 0.0018
#
# Epoch 00122: val_loss did not improve from 0.00143
# Epoch 123/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.3096e-05 - val_loss: 0.0019
#
# Epoch 00123: val_loss did not improve from 0.00143
# Epoch 124/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.2484e-05 - val_loss: 0.0019
#
# Epoch 00124: val_loss did not improve from 0.00143
# Epoch 125/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.3560e-05 - val_loss: 0.0019
#
# Epoch 00125: val_loss did not improve from 0.00143
# Epoch 126/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.3795e-05 - val_loss: 0.0019
#
# Epoch 00126: val_loss did not improve from 0.00143
# Epoch 127/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.4872e-05 - val_loss: 0.0019
#
# Epoch 00127: val_loss did not improve from 0.00143
# Epoch 128/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.2074e-05 - val_loss: 0.0019
#
# Epoch 00128: val_loss did not improve from 0.00143
# Epoch 129/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.3670e-05 - val_loss: 0.0018
#
# Epoch 00129: val_loss did not improve from 0.00143
# Epoch 130/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.0096e-05 - val_loss: 0.0018
#
# Epoch 00130: val_loss did not improve from 0.00143
# Epoch 131/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.1564e-05 - val_loss: 0.0019
#
# Epoch 00131: val_loss did not improve from 0.00143
# Epoch 132/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.2369e-05 - val_loss: 0.0018
#
# Epoch 00132: val_loss did not improve from 0.00143
# Epoch 133/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.0150e-05 - val_loss: 0.0019
#
# Epoch 00133: val_loss did not improve from 0.00143
# Epoch 134/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.0387e-05 - val_loss: 0.0018
#
# Epoch 00134: val_loss did not improve from 0.00143
# Epoch 135/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.9999e-05 - val_loss: 0.0018
#
# Epoch 00135: val_loss did not improve from 0.00143
# Epoch 136/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.9750e-05 - val_loss: 0.0019
#
# Epoch 00136: val_loss did not improve from 0.00143
# Epoch 137/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.7781e-05 - val_loss: 0.0018
#
# Epoch 00137: val_loss did not improve from 0.00143
# Epoch 138/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.8046e-05 - val_loss: 0.0018
#
# Epoch 00138: val_loss did not improve from 0.00143
# Epoch 139/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.7907e-05 - val_loss: 0.0019
#
# Epoch 00139: val_loss did not improve from 0.00143
# Epoch 140/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.9274e-05 - val_loss: 0.0018
#
# Epoch 00140: val_loss did not improve from 0.00143
# Epoch 141/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.8691e-05 - val_loss: 0.0018
#
# Epoch 00141: val_loss did not improve from 0.00143
# Epoch 142/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.8650e-05 - val_loss: 0.0019
#
# Epoch 00142: val_loss did not improve from 0.00143
# Epoch 143/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.8119e-05 - val_loss: 0.0018
#
# Epoch 00143: val_loss did not improve from 0.00143
# Epoch 144/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.7358e-05 - val_loss: 0.0018
#
# Epoch 00144: val_loss did not improve from 0.00143
# Epoch 145/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.6595e-05 - val_loss: 0.0018
#
# Epoch 00145: val_loss did not improve from 0.00143
# Epoch 146/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.6120e-05 - val_loss: 0.0018
#
# Epoch 00146: val_loss did not improve from 0.00143
# Epoch 147/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.6785e-05 - val_loss: 0.0018
#
# Epoch 00147: val_loss did not improve from 0.00143
# Epoch 148/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.8851e-05 - val_loss: 0.0018
#
# Epoch 00148: val_loss did not improve from 0.00143
# Epoch 149/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.7961e-05 - val_loss: 0.0018
#
# Epoch 00149: val_loss did not improve from 0.00143
# Epoch 150/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.7881e-05 - val_loss: 0.0019
#
# Epoch 00150: val_loss did not improve from 0.00143

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_with_augment.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_with_augment.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))
